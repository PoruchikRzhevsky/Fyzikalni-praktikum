# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import uncertainties as u 
from uncertainties import ufloat
from uncertainties.umath import *
from uncertainties import unumpy

#Brownův pohyb

l_0 = 50
l_micro = ufloat(12.7, 0.05)

x = (l_micro * 10**(-2)) / (l_0 * 10**(-6))

print('Magnification =', x)

l5_1 = [11, 13, 20, 13, 9, 11, 3, 11, 5]
l10_1 = [20, 29, 30, 13, 4, 10, 11, 18]
l15_1 = [28, 40, 30, 14, 3, 10, 12]

l5_2 = [8, 19, 10, 13, 7, 7, 7, 28, 14]
l10_2 = [13, 14, 23, 5, 4, 6, 30, 33]
l15_2 = [13, 15, 16, 12, 10, 23, 38]

l5_3 = [6, 5, 16, 11, 3, 15, 6, 9, 15]
l10_3 = [8, 18, 23, 10, 12, 15, 15, 20]
l15_3 = [24, 24, 23, 18, 12, 13, 23]

l5_4 = [6, 9, 13, 9, 10, 8, 19, 7, 7]
l10_4 = [10, 10, 22, 11, 16, 26, 26, 12]
l15_4 = [5, 17, 21, 20, 35, 32, 30]

l5_5 = [16, 10, 6, 12, 9, 6, 5, 13, 10]
l10_5 = [12, 10, 18, 16, 8, 8, 18, 23]
l15_5 = [7, 18, 21, 11, 14, 19, 26]

for ii in range(len(l5_1)):
    l5_1[ii] = ufloat(l5_1[ii], 0.05)**2
    l5_2[ii] = ufloat(l5_2[ii], 0.05)**2
    l5_3[ii] = ufloat(l5_3[ii], 0.05)**2
    l5_4[ii] = ufloat(l5_4[ii], 0.05)**2
    l5_5[ii] = ufloat(l5_5[ii], 0.05)**2

for ii in range(len(l10_1)):
    l10_1[ii] = ufloat(l10_1[ii], 0.05)**2
    l10_2[ii] = ufloat(l10_2[ii], 0.05)**2
    l10_3[ii] = ufloat(l10_3[ii], 0.05)**2
    l10_4[ii] = ufloat(l10_4[ii], 0.05)**2
    l10_5[ii] = ufloat(l10_5[ii], 0.05)**2

for ii in range(len(l15_1)):
    l15_1[ii] = ufloat(l15_1[ii], 0.05)**2
    l15_2[ii] = ufloat(l15_2[ii], 0.05)**2
    l15_3[ii] = ufloat(l15_3[ii], 0.05)**2
    l15_4[ii] = ufloat(l15_4[ii], 0.05)**2
    l15_5[ii] = ufloat(l15_5[ii], 0.05)**2

l5_1_val = []
l10_1_val = []
l15_1_val = []

l5_2_val = []
l10_2_val = []
l15_2_val = []

l5_3_val = []
l10_3_val = []
l15_3_val = []

l5_4_val = []
l10_4_val = []
l15_4_val = []

l5_5_val = []
l10_5_val = []
l15_5_val = []

for ii in range(len(l5_1)):
    l5_1_val.append(l5_1[ii].nominal_value)
    l5_2_val.append(l5_2[ii].nominal_value)
    l5_3_val.append(l5_3[ii].nominal_value)
    l5_4_val.append(l5_4[ii].nominal_value)
    l5_5_val.append(l5_5[ii].nominal_value)

for ii in range(len(l10_1)):
    l10_1_val.append(l10_1[ii].nominal_value)
    l10_2_val.append(l10_2[ii].nominal_value)
    l10_3_val.append(l10_3[ii].nominal_value)
    l10_4_val.append(l10_4[ii].nominal_value)
    l10_5_val.append(l10_5[ii].nominal_value)

for ii in range(len(l15_1)):
    l15_1_val.append(l15_1[ii].nominal_value)
    l15_2_val.append(l15_2[ii].nominal_value)
    l15_3_val.append(l15_3[ii].nominal_value)
    l15_4_val.append(l15_4[ii].nominal_value)
    l15_5_val.append(l15_5[ii].nominal_value)

l5_1_mean = ufloat(np.mean(l5_1).nominal_value, sqrt(np.mean(l5_1).std_dev**2 + np.std(l5_1_val)**2))
l10_1_mean = ufloat(np.mean(l10_1).nominal_value, sqrt(np.mean(l10_1).std_dev**2 + np.std(l10_1_val)**2))
l15_1_mean = ufloat(np.mean(l15_1).nominal_value, sqrt(np.mean(l15_1).std_dev**2 + np.std(l15_1_val)**2))

l5_2_mean = ufloat(np.mean(l5_2).nominal_value, sqrt(np.mean(l5_2).std_dev**2 + np.std(l5_2_val)**2))
l10_2_mean = ufloat(np.mean(l10_2).nominal_value, sqrt(np.mean(l10_2).std_dev**2 + np.std(l10_2_val)**2))
l15_2_mean = ufloat(np.mean(l15_2).nominal_value, sqrt(np.mean(l15_2).std_dev**2 + np.std(l15_2_val)**2))

l5_3_mean = ufloat(np.mean(l5_3).nominal_value, sqrt(np.mean(l5_3).std_dev**2 + np.std(l5_3_val)**2))
l10_3_mean = ufloat(np.mean(l10_3).nominal_value, sqrt(np.mean(l10_3).std_dev**2 + np.std(l10_3_val)**2))
l15_3_mean = ufloat(np.mean(l15_3).nominal_value, sqrt(np.mean(l15_3).std_dev**2 + np.std(l15_3_val)**2))

l5_4_mean = ufloat(np.mean(l5_4).nominal_value, sqrt(np.mean(l5_4).std_dev**2 + np.std(l5_4_val)**2))
l10_4_mean = ufloat(np.mean(l10_4).nominal_value, sqrt(np.mean(l10_4).std_dev**2 + np.std(l10_4_val)**2))
l15_4_mean = ufloat(np.mean(l15_4).nominal_value, sqrt(np.mean(l15_4).std_dev**2 + np.std(l15_4_val)**2))

l5_5_mean = ufloat(np.mean(l5_5).nominal_value, sqrt(np.mean(l5_5).std_dev**2 + np.std(l5_5_val)**2))
l10_5_mean = ufloat(np.mean(l10_5).nominal_value, sqrt(np.mean(l10_5).std_dev**2 + np.std(l10_5_val)**2))
l15_5_mean = ufloat(np.mean(l15_5).nominal_value, sqrt(np.mean(l15_5).std_dev**2 + np.std(l15_5_val)**2))

print('l5_1 =', l5_1)
print('l10_1 =', l10_1)
print('l15_1 =', l15_1)
print('l5_1_mean =', l5_1_mean.nominal_value, '+-', l5_1_mean.std_dev)
print('l10_1_mean =', l10_1_mean.nominal_value, '+-', l10_1_mean.std_dev)
print('l15_1_mean =', l15_1_mean.nominal_value, '+-', l15_1_mean.std_dev)
print('ratio l10_1 / l5_1 =', l10_1_mean.nominal_value / l5_1_mean.nominal_value)
print('ratio l15_1 / l5_1 =', l15_1_mean.nominal_value / l5_1_mean.nominal_value)

print('l5_2 =', l5_2)
print('l10_2 =', l10_2)
print('l15_2 =', l15_2)
print('l5_2_mean =', l5_2_mean.nominal_value, '+-', l5_2_mean.std_dev)
print('l10_2_mean =', l10_2_mean.nominal_value, '+-', l10_2_mean.std_dev)
print('l15_2_mean =', l15_2_mean.nominal_value, '+-', l15_2_mean.std_dev)
print('ratio l10_2 / l5_2 =', l10_2_mean.nominal_value / l5_2_mean.nominal_value)
print('ratio l15_2 / l5_2 =', l15_2_mean.nominal_value / l5_2_mean.nominal_value)

print('l5_3 =', l5_3)
print('l10_3 =', l10_3)
print('l15_3 =', l15_3)
print('l5_3_mean =', l5_3_mean.nominal_value, '+-', l5_3_mean.std_dev)
print('l10_3_mean =', l10_3_mean.nominal_value, '+-', l10_3_mean.std_dev)
print('l15_3_mean =', l15_3_mean.nominal_value, '+-', l15_3_mean.std_dev)
print('ratio l10_3 / l5_3 =', l10_3_mean.nominal_value / l5_3_mean.nominal_value)
print('ratio l15_3 / l5_3 =', l15_3_mean.nominal_value / l5_3_mean.nominal_value)

print('l5_4 =', l5_4)
print('l10_4 =', l10_4)
print('l15_4 =', l15_4)
print('l5_4_mean =', l5_4_mean.nominal_value, '+-', l5_4_mean.std_dev)
print('l10_4_mean =', l10_4_mean.nominal_value, '+-', l10_4_mean.std_dev)
print('l15_4_mean =', l15_4_mean.nominal_value, '+-', l15_4_mean.std_dev)
print('ratio l10_4 / l5_4 =', l10_4_mean.nominal_value / l5_4_mean.nominal_value)
print('ratio l15_4 / l5_4 =', l15_4_mean.nominal_value / l5_4_mean.nominal_value)

print('l5_5 =', l5_5)
print('l10_5 =', l10_5)
print('l15_5 =', l15_5)
print('l5_5_mean =', l5_5_mean.nominal_value, '+-', l5_5_mean.std_dev)
print('l10_5_mean =', l10_5_mean.nominal_value, '+-', l10_5_mean.std_dev)
print('l15_5_mean =', l15_5_mean.nominal_value, '+-', l15_5_mean.std_dev)
print('ratio l10_5 / l5_5 =', l10_5_mean.nominal_value / l5_5_mean.nominal_value)
print('ratio l15_5 / l5_5 =', l15_5_mean.nominal_value / l5_5_mean.nominal_value)

R = 8.314
N = 6.002*10**(23)
eta = 0.891*10**(-3)
T = 297.65

r5_1 = (2*R*T) / (3 * np.pi * eta * N * l5_1_mean*10**(-3)) * 10**12
r10_1 = (2*R*T) / (3 * np.pi * eta * N * l10_1_mean*10**(-3)) * 10**12
r15_1 = (2*R*T) / (3 * np.pi * eta * N * l15_1_mean*10**(-3)) * 10**12
print('r5_1 =', r5_1)
print('r10_1 =', r10_1)
print('r15_1 =', r15_1)

r5_2 = (2*R*T) / (3 * np.pi * eta * N * l5_2_mean*10**(-3)) * 10**12
r10_2 = (2*R*T) / (3 * np.pi * eta * N * l10_2_mean*10**(-3)) * 10**12
r15_2 = (2*R*T) / (3 * np.pi * eta * N * l15_2_mean*10**(-3)) * 10**12
print('r5_2 =', r5_2)
print('r10_2 =', r10_2)
print('r15_2 =', r15_2)

r5_3 = (2*R*T) / (3 * np.pi * eta * N * l5_3_mean*10**(-3)) * 10**12
r10_3 = (2*R*T) / (3 * np.pi * eta * N * l10_3_mean*10**(-3)) * 10**12
r15_3 = (2*R*T) / (3 * np.pi * eta * N * l15_3_mean*10**(-3)) * 10**12
print('r5_3 =', r5_3)
print('r10_3 =', r10_3)
print('r15_3 =', r15_3)

r5_4 = (2*R*T) / (3 * np.pi * eta * N * l5_4_mean*10**(-3)) * 10**12
r10_4 = (2*R*T) / (3 * np.pi * eta * N * l10_4_mean*10**(-3)) * 10**12
r15_4 = (2*R*T) / (3 * np.pi * eta * N * l15_4_mean*10**(-3)) * 10**12
print('r5_4 =', r5_4)
print('r10_4 =', r10_4)
print('r15_4 =', r15_4)

r5_5 = (2*R*T) / (3 * np.pi * eta * N * l5_5_mean*10**(-3)) * 10**12
r10_5 = (2*R*T) / (3 * np.pi * eta * N * l10_5_mean*10**(-3)) * 10**12
r15_5 = (2*R*T) / (3 * np.pi * eta * N * l15_5_mean*10**(-3)) * 10**12
print('r5_5 =', r5_5)
print('r10_5 =', r10_5)
print('r15_5 =', r15_5)

r_list = [r5_1, r10_1, r15_1, r5_2, r10_2, r15_2, r5_3, r10_3, r15_3, r5_4, r10_4, r15_4, r5_5, r10_5, r15_5]
r_list_val = []

for ii in range(len(r_list)):
    r_list_val.append(r_list[ii].nominal_value)

r_mean = ufloat(np.mean(r_list).nominal_value, sqrt(np.mean(r_list).std_dev**2 + np.std(r_list_val)**2))
print('r_mean =', r_mean)

#Pohyblivost částic

L = 29
S = (0.112*10**(-3))**2 * np.pi/4
e_0 = 1.6*10**(-19)
n = 8.5*10**(28)
m_e = 9.1093837*10**(-31)

data = pd.read_csv('data/data.csv')

data['T'] = data['t'] + 273.15
data['delta T'] = data['T'] - 297.65
data['rho'] = data['R'] * S / L
data['sigma'] = 1 / data['rho']
data['mu'] = L / (e_0 * n * data['R'] * S)
data['alpha'] = ((data['rho'] - data['rho'][0])/data['rho'][0]) / data['delta T']
data['tau'] = data['mu']*m_e / e_0

print(np.mean(data['alpha'][4:]))
print(np.std(data['alpha'][4:]))
 
print(data)

colors = ['#FF7F0E','#D62728','#FFDB58','#2CA02C','#17BECF','#1F77B4','#F0027F']  

plt.rc("font", size=10)
plt.rcParams["font.family"] = "Times New Roman"
fig, ax = plt.subplots(figsize=(10, 10))

# ax.title.set_fontsize(20)
ax.set_xlabel(r"$t$ [$^o$ C]")
ax.xaxis.label.set_fontsize(20)
ax.set_ylabel(r"$\tau \times 10^{14}$ [s]")
ax.yaxis.label.set_fontsize(20)
ax.tick_params(axis="both", which="major", length=10, width=0.5, labelsize=15)
ax.tick_params(axis="both", which="minor", length=5, width=0.5, labelsize=15)
# plt.xticks(rotation=45)
plt.tight_layout()  

ax.scatter(data['t'], data['tau']*10**(14), color=colors[5], linewidth=3)
ax.plot(data['t'], data['tau']*10**(14), color=colors[5], linewidth=3)

plt.show() 

# fig.savefig('images/tau.png', bbox_inches='tight')
# Out:
# Magnification = 2540+/-10
# l5_1 = [121.0+/-1.1, 169.0+/-1.3, 400.0+/-2.0, 169.0+/-1.3, 81.0+/-0.9, 121.0+/-1.1, 9.0+/-0.30000000000000004, 121.0+/-1.1, 25.0+/-0.5]
# l10_1 = [400.0+/-2.0, 841.0+/-2.9000000000000004, 900.0+/-3.0, 169.0+/-1.3, 16.0+/-0.4, 100.0+/-1.0, 121.0+/-1.1, 324.0+/-1.8]
# l15_1 = [784.0+/-2.8000000000000003, 1600.0+/-4.0, 900.0+/-3.0, 196.0+/-1.4000000000000001, 9.0+/-0.30000000000000004, 100.0+/-1.0, 144.0+/-1.2000000000000002]
# l5_1_mean = 135.11111111111111 +- 107.50619620385712
# l10_1_mean = 358.875 +- 317.29096736079646
# l15_1_mean = 533.2857142857143 +- 542.8941966677395
# ratio l10_1 / l5_1 = 2.656147203947368
# ratio l15_1 / l5_1 = 3.947015977443609
# l5_2 = [64.0+/-0.8, 361.0+/-1.9000000000000001, 100.0+/-1.0, 169.0+/-1.3, 49.0+/-0.7000000000000001, 49.0+/-0.7000000000000001, 49.0+/-0.7000000000000001, 784.0+/-2.8000000000000003, 196.0+/-1.4000000000000001]
# ...
